# %%
import numpy as np
import matplotlib.pyplot as plt
from random import randint
import random
import time
# %matplotlib inline
plt.style.use('bmh')
plt.rcParams['figure.figsize'] = (15.0, 3.0)
plt.rcParams['font.size'] = 16

# %%
data = np.loadtxt("SN_m_tot_V2.0.txt")

# %%
plt.plot(data[:,2], data[:,3])
plt.plot(data[:,2], data[:,3]*np.hanning(len(data[:,3])))
plt.plot()
# Out:
# []

# %%
plt.plot(abs(np.fft.fft(data[:,3]*np.hanning(len(data[:,3])))))

plt.xlim(0,len(data[:,3])/2)
#plt.xlim(7,52*7)
plt.semilogy()
#np.fft.fftfreq(10)
# Out:
# []

# %%
plt.hist(np.diff(data[:,2]))
# Out:
# (array([ 406.,    0.,  130.,    0.,  332.,  535.,    0., 1606.,    0.,
#          203.]),
#  array([0.081 , 0.0814, 0.0818, 0.0822, 0.0826, 0.083 , 0.0834, 0.0838,
#         0.0842, 0.0846, 0.085 ]),
#  <a list of 10 Patch objects>)
