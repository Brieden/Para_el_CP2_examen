# %%
import numpy as np
import matplotlib.pyplot as plt
from random import randint
import sympy as sym
from scipy import misc as mis
import random
import time
# %matplotlib inline
plt.style.use('bmh')
plt.rcParams['figure.figsize'] = (15.0, 6.0)
plt.rcParams['font.size'] = 16

# %% [markdown]
# # Aufgabe 2.1

# %%
n = 100
a = 5
b = -2
realisierungen = 500000
plotten = 0
finale_Punkte = []

for r in range(realisierungen):
    r_n = np.random.rand(n)
    l_n = np.round(a * r_n + b)
    finale_Punkte.append(sum(l_n))

# %%
#    if plotten:
#        plt.plot(np.cumsum(l_n), lw=1.0)
#if  plotten:
#    plt.show()


plt.hist(finale_Punkte, normed=True, bins=47, label="Verteilung der random walks")
x = np.linspace(min(finale_Punkte),max(finale_Punkte),100)

D = a**2/12
x_bar = 0.5 * a + b
normal_distribution = lambda x: 1/np.sqrt(2 * np.pi * D * n) * np.exp(-(x - n * x_bar)**2/(2 * D * n))
plt.plot(x, normal_distribution(x), label="berechnete Normalverteilung")
plt.xlabel("Abstand vom Ursprung ")
plt.ylabel("Normierte Anzahl")
plt.legend()
if 1:
    plt.show()
    print(np.unique(l_n, return_counts=True))
    plt.hist(l_n.flatten(), bins=range(int(l_n.min()), int(l_n.max()+3)))
    plt.show()
# Out:
# /usr/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# (array([-2., -1., -0.,  1.,  2.,  3.]), array([ 5, 24, 22, 18, 16, 15]))

# %% [markdown]
# Mögliche Werte und Verteilung:
#
# $r_n$ ∈ (0,1)
#
# für a,b ∈ $ℝ_+$
#
# $l_n$ ∈ (round(b), round(a+b))

# %% [markdown]
# P{round(b)+1, ..., round( a + b - 1)} = steps / a ggf -1
#
# P{round(b), round( a + b)} = steps / (a * 2)

# %%
n = 1.1
ñ = 1.1
D = 1.1
normal_distribution = lambda x: 1/np.sqrt(2 * np.pi * D * n) * np.exp(-(x - n * ñ)**2/(2 * D * n))
#normal_distribution = lambda x: np.exp(-(x - n * ñ)^2)#/(2 * D * n))

normal_distribution(2.1)
# Out:
# 0.26143678554037897

# %% [markdown]
# # Aufgabe 2.2

# %%
p_x = lambda x: 1 / np.sqrt(2 * np.pi * σ**2) * np.exp(- x**2 / (2 * σ**2))

# %%
if 0:
        plt.hist(X, bins=100, normed=True)
        x = np.linspace(min(X), max(X), 50)
        plt.plot(x, p_x(x)), plt.show()

# %%
σ = 1
μ = 0
σs = [ σ**2, 3*σ**4, 15*σ**6, 105*σ**8, 945*σ**10]
zehn = ["10^3","10^4","10^5","10^6","10^7","10^8","10^9"]
for ni, n in enumerate([1e3, 1e4, 1e5, 1e6, 1e7, 1e8]):
    X = np.random.randn(int(n)) * σ + μ
    x, y = [], []
    for m in range(len(σs)):
        x.append(2*(m + 1))
        y.append(abs((sum(X**(2*(m+1)))/len(X) - σs[m])/(σs[m])))
    plt.plot(x, y, "x--", c = "C%i"%ni, label=zehn[ni], lw=0.1)

plt.semilogy()
plt.xlabel("Moment k")
plt.ylabel("positiv relative errors")
plt.legend()

# %%
# Out:
# (0.002666492726091538,
#  0.9972356970514392,
#  0.015782060369202378,
#  2.9861163437212976)

# %%
n = np.array([1,2,3,4,5])
funk = 2*n-1
mis.factorial2(funk)
# Out:
# /usr/lib/python3.6/site-packages/ipykernel_launcher.py:3: DeprecationWarning: `factorial2` is deprecated!
# Importing `factorial2` from scipy.misc is deprecated in scipy 1.0.0. Use `scipy.special.factorial2` instead.
#   This is separate from the ipykernel package so we can avoid doing imports until
# array([  1.,   3.,  15., 105., 945.])

# %% [markdown]
# # Aufgabe 2.3

# %%
def X():
    return random.random()

ε = 0.005
G1 = 0.1 - ε
G2 = 3/4 - ε
G3 = 1/2 - ε

M = round(G1 * X() / 0.5) + round(G2 * X())
M
# Out:
# 0.6592748192884639

# %%
?

# %%
x = np.linspace(0,1,30)
p = 0.9
X = p * x /0.5
plt.plot(x, np.round(X)), X,
# Out:
# ([<matplotlib.lines.Line2D at 0x7ff5ffa43eb8>],
#  array([0.        , 0.06206897, 0.12413793, 0.1862069 , 0.24827586,
#         0.31034483, 0.37241379, 0.43448276, 0.49655172, 0.55862069,
#         0.62068966, 0.68275862, 0.74482759, 0.80689655, 0.86896552,
#         0.93103448, 0.99310345, 1.05517241, 1.11724138, 1.17931034,
#         1.24137931, 1.30344828, 1.36551724, 1.42758621, 1.48965517,
#         1.55172414, 1.6137931 , 1.67586207, 1.73793103, 1.8       ]))

# %%
plt.hist()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# mtrand.pyx in mtrand.RandomState.choice()
#
# TypeError: 'float' object cannot be interpreted as an integer
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-127-f9e24a9986e5> in <module>()
# ----> 1 plt.hist(np.random.choice(.5, 100))
#
# mtrand.pyx in mtrand.RandomState.choice()
#
# ValueError: a must be 1-dimensional or an integer

# %%
# ?np.random.choice(5)
